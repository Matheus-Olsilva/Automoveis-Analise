# %% [markdown]
# ### Análise de Dados Para Estudo
# #### Dataset Kagle, Projeto Rank de Bilionarios

# %%
import pandas as pd
import sqlite3

# %%
#Importar aquivo csv
df = pd.read_csv('C:/Users/Mathe/OneDrive/Cods/Datasets/billionaires.csv')

# %%
df.head(10)
# Out:
#                       Name  Rank  Year  Company_Founded  \
# 0               Bill Gates     1  1996             1975
# 1               Bill Gates     1  2001             1975
# 2               Bill Gates     1  2014             1975
# 3           Warren Buffett     2  1996             1962
# 4           Warren Buffett     2  2001             1962
# 5         Carlos Slim Helu     2  2014             1990
# 6  Oeri Hoffman and Sacher     3  1996             1896
# 7               Paul Allen     3  2001             1975
# 8           Amancio Ortega     3  2014             1975
# 9             Lee Shau Kee     4  1996             1976
#
#                  Company_Name Company_Relationship   Company_Sector  \
# 0                   Microsoft              founder         Software
# 1                   Microsoft              founder         Software
# 2                   Microsoft              founder         Software
# 3          Berkshire Hathaway              founder          Finance
# ...

# %%
#conexão com banco de dados
cnn = sqlite3.connect('C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo02.db')

# %%
df.to_sql('Ranking3', cnn)
# Out:
# 2614

# %%
#Carregar a extensão SQL
# %sql sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo02.db

# %%
# %%sql
# SELECT count(*) as contagem
# FROM Bilionarios
# Out:
#    sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo01.db
#  * sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo02.db
# Done.
# [(2614,)]

# %%
# %%sql
# SELECT count(Company_Name) as contagem, Rank, Company_Name, Name
# FROM Bilionarios
# Group By Rank, Company_Name, Name
# Order By Rank
# LIMIT 10;
# Out:
#    sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo01.db
#  * sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo02.db
# Done.
# [(3, 1, 'Microsoft', 'Bill Gates', 'North America'),
#  (2, 2, 'Berkshire Hathaway', 'Warren Buffett', 'North America'),
#  (1, 2, 'Telmex', 'Carlos Slim Helu', 'Latin America'),
#  (1, 3, 'F. Hoffmann-La Roche', 'Oeri Hoffman and Sacher', 'Europe'),
#  (1, 3, 'Microsoft', 'Paul Allen', 'North America'),
#  (1, 3, 'Zara', 'Amancio Ortega', 'Europe'),
#  (1, 4, 'Berkshire Hathaway', 'Warren Buffett', 'North America'),
#  (1, 4, 'Henderson Land Development', 'Lee Shau Kee', 'East Asia'),
#  (1, 4, 'Oracle', 'Larry Ellison', 'North America'),
#  (1, 5, 'Aldi', 'Theo and Karl Albrecht', 'Europe')]

# %%
# %%sql
# SELECT Rank, count(Location_Region) as Contagem, Location_Region, Name, Company_Name, Year
# FROM Bilionarios
# Group by Location_Region, rank
# Having Rank <=3
# Order by Rank
# Out:
#    sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo01.db
#  * sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo02.db
# Done.
# [(1, 3, 'North America', 'Bill Gates', 'Microsoft', 1996),
#  (2, 1, 'Latin America', 'Carlos Slim Helu', 'Telmex', 2014),
#  (2, 2, 'North America', 'Warren Buffett', 'Berkshire Hathaway', 1996),
#  (3, 2, 'Europe', 'Oeri Hoffman and Sacher', 'F. Hoffmann-La Roche', 1996),
#  (3, 1, 'North America', 'Paul Allen', 'Microsoft', 2001)]

# %%
# %%sql
#
# CREATE TABLE Ranking4 AS
# SELECT Rank, count(Location_Region) as Contagem, Location_Region, Name, Company_Name, Year
# FROM Ranking3
# GROUP BY Location_Region, Rank
# HAVING Rank <= 3
# ORDER BY Rank;
# Out:
#    sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo01.db
#  * sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo02.db
# Done.
# []

# %%
# %%sql
# Select * From Ranking4
# Out:
#    sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo01.db
#  * sqlite:///C:/Users/Mathe/OneDrive/Cods/DataBase/DBestudo02.db
# Done.
# [(1, 3, 'North America', 'Bill Gates', 'Microsoft', 1996),
#  (2, 1, 'Latin America', 'Carlos Slim Helu', 'Telmex', 2014),
#  (2, 2, 'North America', 'Warren Buffett', 'Berkshire Hathaway', 1996),
#  (3, 2, 'Europe', 'Oeri Hoffman and Sacher', 'F. Hoffmann-La Roche', 1996),
#  (3, 1, 'North America', 'Paul Allen', 'Microsoft', 2001)]

# %% [markdown]
# ### Salvando em csv

# %%
query = cnn.execute('SELECT * FROM Ranking4')

# %%
cols = [coluna[0] for coluna in query.description]

# %%
cols
# Out:
# ['Rank', 'Contagem', 'Location_Region', 'Name', 'Company_Name', 'Year']

# %%
resultado = pd.DataFrame.from_records(data=query.fetchall(), columns = cols)

# %%
resultado.head()
# Out:
#    Rank  Contagem Location_Region                     Name  \
# 0     1         3   North America               Bill Gates
# 1     2         1   Latin America         Carlos Slim Helu
# 2     2         2   North America           Warren Buffett
# 3     3         2          Europe  Oeri Hoffman and Sacher
# 4     3         1   North America               Paul Allen
#
#            Company_Name  Year
# 0             Microsoft  1996
# 1                Telmex  2014
# 2    Berkshire Hathaway  1996
# 3  F. Hoffmann-La Roche  1996
# 4             Microsoft  2001

# %%
#salva em formato csv
resultado.to_csv('C:/Users/Mathe/OneDrive/Cods/Datasets/ranking.csv', index = False)
